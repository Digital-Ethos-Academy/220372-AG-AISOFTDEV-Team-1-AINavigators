# %% [markdown]
# ### Configurig Models and Vars

# %%
import sys
import os

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Only need to go up one level since we're in the Python Notebooks directory
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
except IndexError:
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact, clean_llm_output

client, model_name, api_provider = setup_llm_client(model_name="gemini-2.5-pro")

# Load the application code from Day 3 to provide context for test generation
# TODO: potentially change this path depending on project structure
main_code = load_artifact("Artifacts/backend/app/main.py")
crud_code = load_artifact("Artifacts/backend/app/crud.py")
if not main_code:
    print("Warning: Could not load app/main.py. Lab may not function correctly.")
# Out:
# 2025-11-05 16:10:16,530 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None

# %% [markdown]
# ### Generating Tests with Fixture
# **Task:** Generate `pytest` tests for the ideal or "happy path" scenarios of your CRUD endpoints.

# %%
# Generate the pytest fixture for an isolated test database
db_fixture_prompt = f"""
You are a senior QA Engineer. Generate a pytest configuration file (conftest.py) that is compatible with the StaffAlloc FastAPI backend located in `Artifacts/backend/app`.

FastAPI main.py Code:
{main_code}

CRUD Code:
{crud_code}

Context:
- Tests run from the repository root, so the backend package directory `Artifacts/backend` must be added to `sys.path` in the fixture setup.
- The FastAPI application expects to be imported as the package `app`.

Requirements:
1. Output a `conftest.py` file that configures pytest fixtures for fully isolated database testing.
2. Use an in-memory SQLite database (`sqlite:///:memory:`) with SQLAlchemy.
3. Import the necessary modules: `pytest`, `TestClient` from `fastapi.testclient`, `create_engine`, `sessionmaker`, and `StaticPool` from SQLAlchemy.
4. Add `Artifacts/backend` to `sys.path` so `import app` works when tests run from the repo root.
5. Import `Base` from `app.models`, `create_app` from `app.main`, `settings` from `app.core.config`, and `get_db` from `app.db.session`.
6. Before creating the app instance, set `settings.API_V1_STR = ""` to remove the version prefix from route paths during tests, then call `create_app()` to get the FastAPI app.
7. Create a database engine with `StaticPool` for the in-memory SQLite database.
8. Create a `TestingSessionLocal` sessionmaker bound to the test engine.
9. Define an `override_get_db()` generator that yields a test database session and closes it afterward.
10. Override the app's `get_db` dependency: `app.dependency_overrides[get_db] = override_get_db`.
11. Define a pytest fixture named `client` with `scope="function"` that:
    - Creates all database tables using `Base.metadata.create_all(bind=engine)` before each test.
    - Yields a `TestClient(app)` instance.
    - Drops all tables using `Base.metadata.drop_all(bind=engine)` after each test.
12. Provide additional fixtures for common test data:
    - `user_data`: Returns a dict with valid user test data.
    - `role_data`: Returns a dict with valid role test data.
    - `lcat_data`: Returns a dict with valid LCAT test data.
    - `project_data`: Returns a dict with valid project test data.

Output only valid Python code for `conftest.py` with proper imports and fixtures. This file will be used by all test files.
"""

print("--- Generating Pytest DB Fixture ---")
if main_code:
    generated_db_fixture = get_completion(db_fixture_prompt, client, model_name, api_provider)
    cleaned_fixture = clean_llm_output(generated_db_fixture, language='python')
    print(cleaned_fixture)
    save_artifact(cleaned_fixture, "Artifacts/Tests/conftest.py", overwrite=True)
else:
    print("Skipping fixture generation because app context is missing.")

# Create comprehensive happy path tests for all CRUD operations
happy_path_tests_prompt = f"""
You are a senior QA Engineer. Create comprehensive happy path tests for all api operations in a FastAPI application using pytest fixtures.

FastAPI Application Code:
{main_code}


Requirements:
1. Import pytest and TestClient from fastapi.testclient
2. Use the fixtures defined in conftest.py (client, user_data, role_data, lcat_data, project_data)
3. Create test functions for each CRUD operation in the following modules:

Users:
- test_create_user: Create a user and verify all fields
- test_get_user: Create and then retrieve a user
- test_get_users: Create multiple users and list them
- test_update_user: Create, update, and verify changes
- test_delete_user: Create and then delete a user

Roles:
- test_create_role: Create a role and verify fields
- test_get_role: Create and retrieve a role
- test_get_roles: Create multiple roles and list them
- test_update_role: Create, update, and verify changes
- test_delete_role: Create and delete a role

LCATs:
- test_create_lcat: Create an LCAT and verify fields
- test_get_lcat: Create and retrieve an LCAT
- test_get_lcats: Create multiple LCATs and list them
- test_update_lcat: Create, update, and verify changes
- test_delete_lcat: Create and delete an LCAT

Projects:
- test_create_project: Create a project and verify fields
- test_get_project: Create and retrieve a project
- test_get_projects: Create multiple projects and list them
- test_update_project: Create, update, and verify changes
- test_delete_project: Create and delete a project
- test_get_projects_for_user: Create project assignments and verify user's projects
- test_get_projects_managed_by_user: Create projects with manager and verify

ProjectAssignments:
- test_create_project_assignment: Create assignment and verify fields
- test_get_project_assignment: Create and retrieve an assignment
- test_get_project_assignments: Create multiple assignments and list them
- test_update_project_assignment: Create, update, and verify changes
- test_delete_project_assignment: Create and delete an assignment
- test_get_assignments_for_project: Create assignments and verify project's assignments
- test_get_assignments_for_user: Create assignments and verify user's assignments

Allocations:
- test_create_allocation: Create allocation and verify fields
- test_get_allocation: Create and retrieve an allocation
- test_get_allocations: Create multiple allocations and list them
- test_update_allocation: Create, update, and verify changes
- test_delete_allocation: Create and delete an allocation
- test_get_allocations_for_assignment: Create allocations and verify assignment's allocations
- test_get_user_allocation_summary: Create allocations and verify user's summary

For each test:
1. Use the appropriate fixture for test data
2. Create any required parent/related entities first
3. Make the API call using the client fixture
4. Assert the correct status code (usually 200 for success)
5. Verify the response data matches the input data
6. For list endpoints, verify pagination works
7. For delete operations, verify the item cannot be retrieved afterward

Output Format:
- Group tests by entity using comments (e.g., # User Tests, # Role Tests, etc.)
- Include proper type hints for the client fixture
- Use descriptive test names that indicate the operation being tested
- Add brief docstrings explaining the test's purpose
- Handle any required relationships between entities

Output only valid Python test functions that use the fixtures from conftest.py.
"""

print("\n--- Generating Happy Path Tests ---")
if main_code:
    happy_path_tests = get_completion(happy_path_tests_prompt, client, model_name, api_provider)
    cleaned_tests = clean_llm_output(happy_path_tests, language='python')
    print(cleaned_tests)
    save_artifact(cleaned_tests, "Artifacts/tests/test_crud_happy_path.py", overwrite=True)
else:
    print("Skipping test generation because app context is missing.")
# Out:
# --- Generating Pytest DB Fixture ---
# # conftest.py
#
# """
# Pytest configuration file for the FastAPI application.
#
# This file sets up fixtures for database testing, ensuring each test runs in
# complete isolation with a fresh in-memory database.
#
# Key components:
# - In-memory SQLite database engine (`sqlite:///:memory:`).
# - `StaticPool` to maintain a single connection for the in-memory DB's lifetime.
# - A dependency override for FastAPI's `get_db` to use the test database session.
# - A function-scoped `client` fixture that creates and tears down the database
#   schema for each test, providing a `TestClient` instance.
# - Reusable data fixtures for common models to keep tests DRY.
# """
#
# import pytest
# from fastapi.testclient import TestClient
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
# from sqlalchemy.pool import StaticPool
#
# # Assume your main application, SQLAlchemy Base, and get_db dependency
# # are defined in `main.py`. Adjust the import path if your project
# # structure is different (e.g., from app.main import ...).
# from main import Base, app, get_db
#
# # --- Test Database Setup ---
#
# # Define the connection string for an in-memory SQLite database.
# # This provides a fast and ephemeral database perfect for testing.
# SQLALCHEMY_DATABASE_URL = "sqlite:///:memory:"
#
# # Create the SQLAlchemy engine for the test database.
# # - `connect_args={"check_same_thread": False}` is required for SQLite.
# # - `poolclass=StaticPool` ensures that the same connection is used across
# #   the session, which is necessary for the in-memory database to persist
# #   within a single test function.
# engine = create_engine(
#     SQLALCHEMY_DATABASE_URL,
#     connect_args={"check_same_thread": False},
#     poolclass=StaticPool,
# )
#
# # Create a sessionmaker that will be used to create sessions for the test database.
# TestingSessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
#
#
# # --- Dependency Override ---
#
# def override_get_db():
#     """
#     A dependency override for FastAPI's `get_db`.
#
#     This function is a generator that creates a new database session from our
#     `TestingSessionLocal` for each incoming request during testing. It ensures
#     the session is always closed, even if errors occur.
#     """
#     db = TestingSessionLocal()
#     try:
#         yield db
#     finally:
#         db.close()
#
#
# # Apply the override. This tells the FastAPI application to use `override_get_db`
# # instead of the production `get_db` function for the duration of the tests.
# app.dependency_overrides[get_db] = override_get_db
#
#
# # --- Core Test Fixtures ---
#
# @pytest.fixture(scope="function")
# def client():
#     """
#     Pytest fixture to provide a test client and manage the database lifecycle.
#
#     This fixture is function-scoped, meaning it will execute its setup and
#     teardown logic for every single test function.
#
#     Setup:
#     1. Creates all database tables defined in the SQLAlchemy models (Base.metadata).
#
#     Yields:
#     2. A `TestClient` instance that can be used to make HTTP requests to the app.
#
#     Teardown:
#     3. Drops all database tables, ensuring a clean slate for the next test.
#     """
#     # Create the database tables
#     Base.metadata.create_all(bind=engine)
#
#     # Yield the test client
#     with TestClient(app) as c:
#         yield c
#
#     # Drop the database tables
#     Base.metadata.drop_all(bind=engine)
#
#
# # --- Reusable Data Fixtures ---
#
# @pytest.fixture(scope="session")
# def user_data() -> dict:
#     """Provides a dictionary with valid data for creating a new user."""
#     return {
#         "email": "test.user@example.com",
#         "full_name": "Test User",
#         "system_role": "user",
#         "is_active": True,
#     }
#
#
# @pytest.fixture(scope="session")
# def role_data() -> dict:
#     """Provides a dictionary with valid data for creating a new project role."""
#     return {"name": "Software Engineer", "description": "Develops software solutions."}
#
#
# @pytest.fixture(scope="session")
# def lcat_data() -> dict:
#     """Provides a dictionary with valid data for creating a new LCAT."""
#     return {"name": "SE-II", "description": "Software Engineer, Level 2"}
#
#
# @pytest.fixture(scope="session")
# def project_data() -> dict:
#     """Provides a dictionary with valid data for creating a new project."""
#     return {
#         "name": "Project Phoenix",
#         "code": "PHX-001",
#         "description": "A next-generation staff allocation system.",
#         "start_date": "2024-01-01",
#         "end_date": "2025-12-31",
#     }
#
# --- Generating Happy Path Tests ---
# # conftest.py
#
# """
# Pytest configuration file for the FastAPI application.
#
# This file sets up fixtures for database testing, ensuring each test runs in
# complete isolation with a fresh in-memory database.
#
# Key components:
# - In-memory SQLite database engine (`sqlite:///:memory:`).
# - `StaticPool` to maintain a single connection for the in-memory DB's lifetime.
# - A dependency override for FastAPI's `get_db` to use the test database session.
# - A function-scoped `client` fixture that creates and tears down the database
#   schema for each test, providing a `TestClient` instance.
# - Reusable data fixtures for common models to keep tests DRY.
# """
#
# import pytest
# from fastapi.testclient import TestClient
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
# from sqlalchemy.pool import StaticPool
#
# # Assume your main application, SQLAlchemy Base, and get_db dependency
# # are defined in `main.py`. Adjust the import path if your project
# # structure is different (e.g., from app.main import ...).
# from main import Base, app, get_db
#
# # --- Test Database Setup ---
#
# # Define the connection string for an in-memory SQLite database.
# # This provides a fast and ephemeral database perfect for testing.
# SQLALCHEMY_DATABASE_URL = "sqlite:///:memory:"
#
# # Create the SQLAlchemy engine for the test database.
# # - `connect_args={"check_same_thread": False}` is required for SQLite.
# # - `poolclass=StaticPool` ensures that the same connection is used across
# #   the session, which is necessary for the in-memory database to persist
# #   within a single test function.
# engine = create_engine(
#     SQLALCHEMY_DATABASE_URL,
#     connect_args={"check_same_thread": False},
#     poolclass=StaticPool,
# )
#
# # Create a sessionmaker that will be used to create sessions for the test database.
# TestingSessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
#
#
# # --- Dependency Override ---
#
# def override_get_db():
#     """
#     A dependency override for FastAPI's `get_db`.
#
#     This function is a generator that creates a new database session from our
#     `TestingSessionLocal` for each incoming request during testing. It ensures
#     the session is always closed, even if errors occur.
#     """
#     db = TestingSessionLocal()
#     try:
#         yield db
#     finally:
#         db.close()
#
#
# # Apply the override. This tells the FastAPI application to use `override_get_db`
# # instead of the production `get_db` function for the duration of the tests.
# app.dependency_overrides[get_db] = override_get_db
#
#
# # --- Core Test Fixtures ---
#
# @pytest.fixture(scope="function")
# def client():
#     """
#     Pytest fixture to provide a test client and manage the database lifecycle.
#
#     This fixture is function-scoped, meaning it will execute its setup and
#     teardown logic for every single test function.
#
#     Setup:
#     1. Creates all database tables defined in the SQLAlchemy models (Base.metadata).
#
#     Yields:
#     2. A `TestClient` instance that can be used to make HTTP requests to the app.
#
#     Teardown:
#     3. Drops all database tables, ensuring a clean slate for the next test.
#     """
#     # Create the database tables
#     Base.metadata.create_all(bind=engine)
#
#     # Yield the test client
#     with TestClient(app) as c:
#         yield c
#
#     # Drop the database tables
#     Base.metadata.drop_all(bind=engine)
#
#
# # --- Reusable Data Fixtures ---
#
# @pytest.fixture(scope="session")
# def user_data() -> dict:
#     """Provides a dictionary with valid data for creating a new user."""
#     return {
#         "email": "test.user@example.com",
#         "full_name": "Test User",
#         "system_role": "user",
#         "is_active": True,
#     }
#
#
# @pytest.fixture(scope="session")
# def role_data() -> dict:
#     """Provides a dictionary with valid data for creating a new project role."""
#     return {"name": "Software Engineer", "description": "Develops software solutions."}
#
#
# @pytest.fixture(scope="session")
# def lcat_data() -> dict:
#     """Provides a dictionary with valid data for creating a new LCAT."""
#     return {"name": "SE-II", "description": "Software Engineer, Level 2"}
#
#
# @pytest.fixture(scope="session")
# def project_data() -> dict:
#     """Provides a dictionary with valid data for creating a new project."""
#     return {
#         "name": "Project Phoenix",
#         "code": "PHX-001",
#         "description": "A next-generation staff allocation system.",
#         "start_date": "2024-01-01",
#         "end_date": "2025-12-31",
#     }
#
# --- Generating Happy Path Tests ---
# # tests/test_crud_happy_path.py
#
# import datetime
# from typing import Dict, Any
#
# import pytest
# from fastapi.testclient import TestClient
#
# # Note: The following fixtures are assumed to be defined in a `conftest.py` file.
# # @pytest.fixture
# # def client() -> TestClient: ...
# #
# # @pytest.fixture
# # def user_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def role_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def lcat_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def project_data() -> Dict[str, Any]: ...
#
#
# # --------------------------------------------------------------------------------
# # User Tests
# # --------------------------------------------------------------------------------
#
# def test_create_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests successful creation of a new user."""
#     response = client.post("/users/", json=user_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["email"] == user_data["email"]
#     assert data["full_name"] == user_data["full_name"]
#     assert data["system_role"] == user_data["system_role"]
#     assert data["is_active"] is True
#     assert "id" in data
#     assert "password_hash" not in data  # Ensure password hash is not returned
#
#
# def test_get_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests retrieving a single user by ID."""
#     # Create user first
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Retrieve the user
#     get_response = client.get(f"/users/{user_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == user_id
#     assert data["email"] == user_data["email"]
#
#
# def test_get_users(client: TestClient, user_data: Dict[str, Any]):
#     """Tests retrieving a list of users with pagination."""
#     # Create a couple of users
#     user_data_1 = user_data.copy()
#     user_data_2 = user_data.copy()
#     user_data_2["email"] = "jane.doe@example.com"
#     user_data_2["full_name"] = "Jane Doe"
#     client.post("/users/", json=user_data_1)
#     client.post("/users/", json=user_data_2)
#
#     # Get the list
#     response = client.get("/users/?skip=0&limit=10")
#     assert response.status_code == 200
#     data = response.json()
#     assert isinstance(data, list)
#     assert len(data) >= 2
#     assert user_data_1["email"] in [u["email"] for u in data]
#     assert user_data_2["email"] in [u["email"] for u in data]
#
#
# def test_update_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests updating an existing user's information."""
#     # Create user
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Update user
#     update_payload = {"full_name": "John Updated Doe", "is_active": False}
#     update_response = client.put(f"/users/{user_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["id"] == user_id
#     assert data["full_name"] == "John Updated Doe"
#     assert data["is_active"] is False
#     assert data["email"] == user_data["email"]  # Email should not have changed
#
#
# def test_delete_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests deleting a user."""
#     # Create user
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Delete user
#     delete_response = client.delete(f"/users/{user_id}")
#     assert delete_response.status_code == 200
#     assert delete_response.json()["id"] == user_id
#
#     # Verify user is gone
#     get_response = client.get(f"/users/{user_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # Role Tests
# # --------------------------------------------------------------------------------
#
# def test_create_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests successful creation of a new role."""
#     response = client.post("/roles/", json=role_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == role_data["name"]
#     assert data["description"] == role_data["description"]
#     assert "id" in data
#
#
# def test_get_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests retrieving a single role by ID."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     get_response = client.get(f"/roles/{role_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == role_id
#     assert data["name"] == role_data["name"]
#
#
# def test_get_roles(client: TestClient, role_data: Dict[str, Any]):
#     """Tests retrieving a list of roles."""
#     client.post("/roles/", json=role_data)
#     role_data_2 = {"name": "QA Engineer", "description": "Tests software"}
#     client.post("/roles/", json=role_data_2)
#
#     response = client.get("/roles/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests updating an existing role."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     update_payload = {"name": "Senior Software Engineer", "description": "Builds advanced features"}
#     update_response = client.put(f"/roles/{role_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "Senior Software Engineer"
#     assert data["description"] == "Builds advanced features"
#
#
# def test_delete_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests deleting a role."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/roles/{role_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/roles/{role_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # LCAT Tests
# # --------------------------------------------------------------------------------
#
# def test_create_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests successful creation of a new LCAT."""
#     response = client.post("/lcats/", json=lcat_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == lcat_data["name"]
#     assert data["description"] == lcat_data["description"]
#     assert "id" in data
#
#
# def test_get_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests retrieving a single LCAT by ID."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     get_response = client.get(f"/lcats/{lcat_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == lcat_id
#     assert data["name"] == lcat_data["name"]
#
#
# def test_get_lcats(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests retrieving a list of LCATs."""
#     client.post("/lcats/", json=lcat_data)
#     lcat_data_2 = {"name": "SME II", "description": "Subject Matter Expert II"}
#     client.post("/lcats/", json=lcat_data_2)
#
#     response = client.get("/lcats/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests updating an existing LCAT."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     update_payload = {"name": "SME III", "description": "Senior Subject Matter Expert"}
#     update_response = client.put(f"/lcats/{lcat_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "SME III"
#
#
# def test_delete_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests deleting an LCAT."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/lcats/{lcat_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/lcats/{lcat_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # Project Tests
# # --------------------------------------------------------------------------------
#
# def test_create_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests successful creation of a new project."""
#     response = client.post("/projects/", json=project_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == project_data["name"]
#     assert data["code"] == project_data["code"]
#     assert "id" in data
#
#
# def test_get_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests retrieving a single project by ID."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     get_response = client.get(f"/projects/{project_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == project_id
#     assert data["name"] == project_data["name"]
#
#
# def test_get_projects(client: TestClient, project_data: Dict[str, Any]):
#     """Tests retrieving a list of projects."""
#     client.post("/projects/", json=project_data)
#     project_data_2 = project_data.copy()
#     project_data_2["name"] = "Project Jupiter"
#     project_data_2["code"] = "PROJ-JUP"
#     client.post("/projects/", json=project_data_2)
#
#     response = client.get("/projects/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests updating an existing project."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     update_payload = {"name": "Project Apollo Mission", "is_active": False}
#     update_response = client.put(f"/projects/{project_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "Project Apollo Mission"
#     assert data["is_active"] is False
#
#
# def test_delete_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests deleting a project."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/projects/{project_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/projects/{project_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_projects_for_user(client: TestClient, user_data, project_data, role_data, lcat_data):
#     """Tests retrieving all projects a specific user is assigned to."""
#     user_id = client.post("/users/", json=user_data).json()["id"]
#     project1_id = client.post("/projects/", json=project_data).json()["id"]
#     project2_data = {"name": "Project B", "code": "PROJ-B"}
#     project2_id = client.post("/projects/", json=project2_data).json()["id"]
#     role_id = client.post("/roles/", json=role_data).json()["id"]
#     lcat_id = client.post("/lcats/", json=lcat_data).json()["id"]
#
#     # Assign user to both projects
#     assignment1_data = {"user_id": user_id, "project_id": project1_id, "role_id": role_id, "lcat_id": lcat_id}
#     assignment2_data = {"user_id": user_id, "project_id": project2_id, "role_id": role_id, "lcat_id": lcat_id}
#     client.post("/project-assignments/", json=assignment1_data)
#     client.post("/project-assignments/", json=assignment2_data)
#
#     response = client.get(f"/users/{user_id}/projects")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) == 2
#     project_ids_in_response = {p["id"] for p in data}
#     assert project1_id in project_ids_in_response
#     assert project2_id in project_ids_in_response
#
#
# def test_get_projects_managed_by_user(client: TestClient, user_data, project_data):
#     """Tests retrieving all projects managed by a specific user."""
#     manager_id = client.post("/users/", json=user_data).json()["id"]
#     project_data_1 = project_data.copy()
#     project_data_1["manager_id"] = manager_id
#     project_data_2 = {"name": "Project B", "code": "PROJ-B", "manager_id": manager_id}
#     client.post("/projects/", json=project_data_1)
#     client.post("/projects/", json=project_data_2)
#
#     response = client.get(f"/users/{manager_id}/managed-projects")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) == 2
#     assert all(p["manager_id"] == manager_id for p in data)
#
#
# # --------------------------------------------------------------------------------
# # ProjectAssignment Tests
# # --------------------------------------------------------------------------------
#
# @pytest.fixture
# def assignment_prereqs(client: TestClient, user_data, project_data, role_data, lcat_data) -> Dict[str, int]:
#     """Fixture to create all parent entities for an assignment."""
#     user_id = client.post("/users/", json=user_data).json()["id"]
#     project_id = client.post("/projects/", json=project_data).json()["id"]
#     role_id = client.post("/roles/", json=role_data).json()["id"]
#     lcat_id = client.post("/lcats/", json=lcat_data).json()["id"]
#     return {"user_id": user_id, "project_id": project_id, "role_id": role_id, "lcat_id": lcat_id}
#
#
# def test_create_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests creating a new project assignment."""
#     response = client.post("/project-assignments/", json=assignment_prereqs)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["user_id"] == assignment_prereqs["user_id"]
#     assert data["project_id"] == assignment_prereqs["project_id"]
#     assert data["role_id"] == assignment_prereqs["role_id"]
#     assert data["lcat_id"] == assignment_prereqs["lcat_id"]
#     assert "id" in data
#
#
# def test_get_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving a single project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     get_response = client.get(f"/project-assignments/{assignment_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == assignment_id
#     assert data["user_id"] == assignment_prereqs["user_id"]
#
#
# def test_get_project_assignments(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving a list of project assignments."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     response = client.get("/project-assignments/")
#     assert response.status_code == 200
#     assert len(response.json()) >= 1
#
#
# def test_update_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int], role_data):
#     """Tests updating an existing project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     # Create a new role to update to
#     new_role_data = {"name": "Team Lead", "description": "Leads the team"}
#     new_role_id = client.post("/roles/", json=new_role_data).json()["id"]
#
#     update_payload = {"role_id": new_role_id}
#     update_response = client.put(f"/project-assignments/{assignment_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["role_id"] == new_role_id
#     assert data["user_id"] == assignment_prereqs["user_id"] # Unchanged
#
#
# def test_delete_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests deleting a project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/project-assignments/{assignment_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/project-assignments/{assignment_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_assignments_for_project(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving all assignments for a specific project."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     project_id = assignment_prereqs["project_id"]
#
#     response = client.get(f"/projects/{project_id}/assignments")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["project_id"] == project_id
#     assert "user" in data[0] and data[0]["user"]["id"] == assignment_prereqs["user_id"]
#
#
# def test_get_assignments_for_user(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving all assignments for a specific user."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     user_id = assignment_prereqs["user_id"]
#
#     response = client.get(f"/users/{user_id}/assignments")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["user_id"] == user_id
#     assert "project" in data[0] and data[0]["project"]["id"] == assignment_prereqs["project_id"]
#
#
# # --------------------------------------------------------------------------------
# # Allocation Tests
# # --------------------------------------------------------------------------------
#
# @pytest.fixture
# def allocation_data(client: TestClient, assignment_prereqs: Dict[str, int]) -> Dict[str, Any]:
#     """Fixture to create an assignment and return allocation data."""
#     assignment_id = client.post("/project-assignments/", json=assignment_prereqs).json()["id"]
#     return {
#         "project_assignment_id": assignment_id,
#         "year": datetime.date.today().year,
#         "month": datetime.date.today().month,
#         "allocated_hours": 160
#     }
#
# def test_create_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests creating a new allocation for an assignment."""
#     response = client.post("/allocations/", json=allocation_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["project_assignment_id"] == allocation_data["project_assignment_id"]
#     assert data["year"] == allocation_data["year"]
#     assert data["month"] == allocation_data["month"]
#     assert data["allocated_hours"] == allocation_data["allocated_hours"]
#
#
# def test_get_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving a single allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     get_response = client.get(f"/allocations/{allocation_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == allocation_id
#     assert data["allocated_hours"] == 160
#
#
# def test_get_allocations(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving a list of allocations."""
#     client.post("/allocations/", json=allocation_data)
#     response = client.get("/allocations/")
#     assert response.status_code == 200
#     assert len(response.json()) >= 1
#
#
# def test_update_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests updating an existing allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     update_payload = {"allocated_hours": 80}
#     update_response = client.put(f"/allocations/{allocation_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["allocated_hours"] == 80
#
#
# def test_delete_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests deleting an allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/allocations/{allocation_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/allocations/{allocation_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_allocations_for_assignment(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving all allocations for a specific assignment."""
#     client.post("/allocations/", json=allocation_data)
#     assignment_id = allocation_data["project_assignment_id"]
#
#     response = client.get(f"/project-assignments/{assignment_id}/allocations")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["project_assignment_id"] == assignment_id
#
#
# def test_get_user_allocation_summary(client: TestClient, allocation_data: Dict[str, Any], assignment_prereqs):
#     """Tests calculating the total allocated hours per month for a user."""
#     client.post("/allocations/", json=allocation_data)
#     user_id = assignment_prereqs["user_id"] # User was created in the prereq fixture
#
#     response = client.get(f"/users/{user_id}/allocation-summary")
#     assert response.status_code == 200
#     data = response.json()
#     assert isinstance(data, list)
#     assert len(data) >= 1
#     summary_item = data[0]
#     assert summary_item["year"] == allocation_data["year"]
#     assert summary_item["month"] == allocation_data["month"]
#     assert summary_item["total_hours"] == allocation_data["allocated_hours"]
# # tests/test_crud_happy_path.py
#
# import datetime
# from typing import Dict, Any
#
# import pytest
# from fastapi.testclient import TestClient
#
# # Note: The following fixtures are assumed to be defined in a `conftest.py` file.
# # @pytest.fixture
# # def client() -> TestClient: ...
# #
# # @pytest.fixture
# # def user_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def role_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def lcat_data() -> Dict[str, Any]: ...
# #
# # @pytest.fixture
# # def project_data() -> Dict[str, Any]: ...
#
#
# # --------------------------------------------------------------------------------
# # User Tests
# # --------------------------------------------------------------------------------
#
# def test_create_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests successful creation of a new user."""
#     response = client.post("/users/", json=user_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["email"] == user_data["email"]
#     assert data["full_name"] == user_data["full_name"]
#     assert data["system_role"] == user_data["system_role"]
#     assert data["is_active"] is True
#     assert "id" in data
#     assert "password_hash" not in data  # Ensure password hash is not returned
#
#
# def test_get_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests retrieving a single user by ID."""
#     # Create user first
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Retrieve the user
#     get_response = client.get(f"/users/{user_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == user_id
#     assert data["email"] == user_data["email"]
#
#
# def test_get_users(client: TestClient, user_data: Dict[str, Any]):
#     """Tests retrieving a list of users with pagination."""
#     # Create a couple of users
#     user_data_1 = user_data.copy()
#     user_data_2 = user_data.copy()
#     user_data_2["email"] = "jane.doe@example.com"
#     user_data_2["full_name"] = "Jane Doe"
#     client.post("/users/", json=user_data_1)
#     client.post("/users/", json=user_data_2)
#
#     # Get the list
#     response = client.get("/users/?skip=0&limit=10")
#     assert response.status_code == 200
#     data = response.json()
#     assert isinstance(data, list)
#     assert len(data) >= 2
#     assert user_data_1["email"] in [u["email"] for u in data]
#     assert user_data_2["email"] in [u["email"] for u in data]
#
#
# def test_update_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests updating an existing user's information."""
#     # Create user
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Update user
#     update_payload = {"full_name": "John Updated Doe", "is_active": False}
#     update_response = client.put(f"/users/{user_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["id"] == user_id
#     assert data["full_name"] == "John Updated Doe"
#     assert data["is_active"] is False
#     assert data["email"] == user_data["email"]  # Email should not have changed
#
#
# def test_delete_user(client: TestClient, user_data: Dict[str, Any]):
#     """Tests deleting a user."""
#     # Create user
#     create_response = client.post("/users/", json=user_data)
#     user_id = create_response.json()["id"]
#
#     # Delete user
#     delete_response = client.delete(f"/users/{user_id}")
#     assert delete_response.status_code == 200
#     assert delete_response.json()["id"] == user_id
#
#     # Verify user is gone
#     get_response = client.get(f"/users/{user_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # Role Tests
# # --------------------------------------------------------------------------------
#
# def test_create_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests successful creation of a new role."""
#     response = client.post("/roles/", json=role_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == role_data["name"]
#     assert data["description"] == role_data["description"]
#     assert "id" in data
#
#
# def test_get_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests retrieving a single role by ID."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     get_response = client.get(f"/roles/{role_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == role_id
#     assert data["name"] == role_data["name"]
#
#
# def test_get_roles(client: TestClient, role_data: Dict[str, Any]):
#     """Tests retrieving a list of roles."""
#     client.post("/roles/", json=role_data)
#     role_data_2 = {"name": "QA Engineer", "description": "Tests software"}
#     client.post("/roles/", json=role_data_2)
#
#     response = client.get("/roles/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests updating an existing role."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     update_payload = {"name": "Senior Software Engineer", "description": "Builds advanced features"}
#     update_response = client.put(f"/roles/{role_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "Senior Software Engineer"
#     assert data["description"] == "Builds advanced features"
#
#
# def test_delete_role(client: TestClient, role_data: Dict[str, Any]):
#     """Tests deleting a role."""
#     create_response = client.post("/roles/", json=role_data)
#     role_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/roles/{role_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/roles/{role_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # LCAT Tests
# # --------------------------------------------------------------------------------
#
# def test_create_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests successful creation of a new LCAT."""
#     response = client.post("/lcats/", json=lcat_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == lcat_data["name"]
#     assert data["description"] == lcat_data["description"]
#     assert "id" in data
#
#
# def test_get_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests retrieving a single LCAT by ID."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     get_response = client.get(f"/lcats/{lcat_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == lcat_id
#     assert data["name"] == lcat_data["name"]
#
#
# def test_get_lcats(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests retrieving a list of LCATs."""
#     client.post("/lcats/", json=lcat_data)
#     lcat_data_2 = {"name": "SME II", "description": "Subject Matter Expert II"}
#     client.post("/lcats/", json=lcat_data_2)
#
#     response = client.get("/lcats/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests updating an existing LCAT."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     update_payload = {"name": "SME III", "description": "Senior Subject Matter Expert"}
#     update_response = client.put(f"/lcats/{lcat_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "SME III"
#
#
# def test_delete_lcat(client: TestClient, lcat_data: Dict[str, Any]):
#     """Tests deleting an LCAT."""
#     create_response = client.post("/lcats/", json=lcat_data)
#     lcat_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/lcats/{lcat_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/lcats/{lcat_id}")
#     assert get_response.status_code == 404
#
#
# # --------------------------------------------------------------------------------
# # Project Tests
# # --------------------------------------------------------------------------------
#
# def test_create_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests successful creation of a new project."""
#     response = client.post("/projects/", json=project_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["name"] == project_data["name"]
#     assert data["code"] == project_data["code"]
#     assert "id" in data
#
#
# def test_get_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests retrieving a single project by ID."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     get_response = client.get(f"/projects/{project_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == project_id
#     assert data["name"] == project_data["name"]
#
#
# def test_get_projects(client: TestClient, project_data: Dict[str, Any]):
#     """Tests retrieving a list of projects."""
#     client.post("/projects/", json=project_data)
#     project_data_2 = project_data.copy()
#     project_data_2["name"] = "Project Jupiter"
#     project_data_2["code"] = "PROJ-JUP"
#     client.post("/projects/", json=project_data_2)
#
#     response = client.get("/projects/")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 2
#
#
# def test_update_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests updating an existing project."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     update_payload = {"name": "Project Apollo Mission", "is_active": False}
#     update_response = client.put(f"/projects/{project_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["name"] == "Project Apollo Mission"
#     assert data["is_active"] is False
#
#
# def test_delete_project(client: TestClient, project_data: Dict[str, Any]):
#     """Tests deleting a project."""
#     create_response = client.post("/projects/", json=project_data)
#     project_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/projects/{project_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/projects/{project_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_projects_for_user(client: TestClient, user_data, project_data, role_data, lcat_data):
#     """Tests retrieving all projects a specific user is assigned to."""
#     user_id = client.post("/users/", json=user_data).json()["id"]
#     project1_id = client.post("/projects/", json=project_data).json()["id"]
#     project2_data = {"name": "Project B", "code": "PROJ-B"}
#     project2_id = client.post("/projects/", json=project2_data).json()["id"]
#     role_id = client.post("/roles/", json=role_data).json()["id"]
#     lcat_id = client.post("/lcats/", json=lcat_data).json()["id"]
#
#     # Assign user to both projects
#     assignment1_data = {"user_id": user_id, "project_id": project1_id, "role_id": role_id, "lcat_id": lcat_id}
#     assignment2_data = {"user_id": user_id, "project_id": project2_id, "role_id": role_id, "lcat_id": lcat_id}
#     client.post("/project-assignments/", json=assignment1_data)
#     client.post("/project-assignments/", json=assignment2_data)
#
#     response = client.get(f"/users/{user_id}/projects")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) == 2
#     project_ids_in_response = {p["id"] for p in data}
#     assert project1_id in project_ids_in_response
#     assert project2_id in project_ids_in_response
#
#
# def test_get_projects_managed_by_user(client: TestClient, user_data, project_data):
#     """Tests retrieving all projects managed by a specific user."""
#     manager_id = client.post("/users/", json=user_data).json()["id"]
#     project_data_1 = project_data.copy()
#     project_data_1["manager_id"] = manager_id
#     project_data_2 = {"name": "Project B", "code": "PROJ-B", "manager_id": manager_id}
#     client.post("/projects/", json=project_data_1)
#     client.post("/projects/", json=project_data_2)
#
#     response = client.get(f"/users/{manager_id}/managed-projects")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) == 2
#     assert all(p["manager_id"] == manager_id for p in data)
#
#
# # --------------------------------------------------------------------------------
# # ProjectAssignment Tests
# # --------------------------------------------------------------------------------
#
# @pytest.fixture
# def assignment_prereqs(client: TestClient, user_data, project_data, role_data, lcat_data) -> Dict[str, int]:
#     """Fixture to create all parent entities for an assignment."""
#     user_id = client.post("/users/", json=user_data).json()["id"]
#     project_id = client.post("/projects/", json=project_data).json()["id"]
#     role_id = client.post("/roles/", json=role_data).json()["id"]
#     lcat_id = client.post("/lcats/", json=lcat_data).json()["id"]
#     return {"user_id": user_id, "project_id": project_id, "role_id": role_id, "lcat_id": lcat_id}
#
#
# def test_create_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests creating a new project assignment."""
#     response = client.post("/project-assignments/", json=assignment_prereqs)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["user_id"] == assignment_prereqs["user_id"]
#     assert data["project_id"] == assignment_prereqs["project_id"]
#     assert data["role_id"] == assignment_prereqs["role_id"]
#     assert data["lcat_id"] == assignment_prereqs["lcat_id"]
#     assert "id" in data
#
#
# def test_get_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving a single project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     get_response = client.get(f"/project-assignments/{assignment_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == assignment_id
#     assert data["user_id"] == assignment_prereqs["user_id"]
#
#
# def test_get_project_assignments(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving a list of project assignments."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     response = client.get("/project-assignments/")
#     assert response.status_code == 200
#     assert len(response.json()) >= 1
#
#
# def test_update_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int], role_data):
#     """Tests updating an existing project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     # Create a new role to update to
#     new_role_data = {"name": "Team Lead", "description": "Leads the team"}
#     new_role_id = client.post("/roles/", json=new_role_data).json()["id"]
#
#     update_payload = {"role_id": new_role_id}
#     update_response = client.put(f"/project-assignments/{assignment_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["role_id"] == new_role_id
#     assert data["user_id"] == assignment_prereqs["user_id"] # Unchanged
#
#
# def test_delete_project_assignment(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests deleting a project assignment."""
#     create_response = client.post("/project-assignments/", json=assignment_prereqs)
#     assignment_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/project-assignments/{assignment_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/project-assignments/{assignment_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_assignments_for_project(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving all assignments for a specific project."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     project_id = assignment_prereqs["project_id"]
#
#     response = client.get(f"/projects/{project_id}/assignments")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["project_id"] == project_id
#     assert "user" in data[0] and data[0]["user"]["id"] == assignment_prereqs["user_id"]
#
#
# def test_get_assignments_for_user(client: TestClient, assignment_prereqs: Dict[str, int]):
#     """Tests retrieving all assignments for a specific user."""
#     client.post("/project-assignments/", json=assignment_prereqs)
#     user_id = assignment_prereqs["user_id"]
#
#     response = client.get(f"/users/{user_id}/assignments")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["user_id"] == user_id
#     assert "project" in data[0] and data[0]["project"]["id"] == assignment_prereqs["project_id"]
#
#
# # --------------------------------------------------------------------------------
# # Allocation Tests
# # --------------------------------------------------------------------------------
#
# @pytest.fixture
# def allocation_data(client: TestClient, assignment_prereqs: Dict[str, int]) -> Dict[str, Any]:
#     """Fixture to create an assignment and return allocation data."""
#     assignment_id = client.post("/project-assignments/", json=assignment_prereqs).json()["id"]
#     return {
#         "project_assignment_id": assignment_id,
#         "year": datetime.date.today().year,
#         "month": datetime.date.today().month,
#         "allocated_hours": 160
#     }
#
# def test_create_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests creating a new allocation for an assignment."""
#     response = client.post("/allocations/", json=allocation_data)
#     assert response.status_code == 200
#     data = response.json()
#     assert data["project_assignment_id"] == allocation_data["project_assignment_id"]
#     assert data["year"] == allocation_data["year"]
#     assert data["month"] == allocation_data["month"]
#     assert data["allocated_hours"] == allocation_data["allocated_hours"]
#
#
# def test_get_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving a single allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     get_response = client.get(f"/allocations/{allocation_id}")
#     assert get_response.status_code == 200
#     data = get_response.json()
#     assert data["id"] == allocation_id
#     assert data["allocated_hours"] == 160
#
#
# def test_get_allocations(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving a list of allocations."""
#     client.post("/allocations/", json=allocation_data)
#     response = client.get("/allocations/")
#     assert response.status_code == 200
#     assert len(response.json()) >= 1
#
#
# def test_update_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests updating an existing allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     update_payload = {"allocated_hours": 80}
#     update_response = client.put(f"/allocations/{allocation_id}", json=update_payload)
#     assert update_response.status_code == 200
#     data = update_response.json()
#     assert data["allocated_hours"] == 80
#
#
# def test_delete_allocation(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests deleting an allocation."""
#     create_response = client.post("/allocations/", json=allocation_data)
#     allocation_id = create_response.json()["id"]
#
#     delete_response = client.delete(f"/allocations/{allocation_id}")
#     assert delete_response.status_code == 200
#
#     get_response = client.get(f"/allocations/{allocation_id}")
#     assert get_response.status_code == 404
#
#
# def test_get_allocations_for_assignment(client: TestClient, allocation_data: Dict[str, Any]):
#     """Tests retrieving all allocations for a specific assignment."""
#     client.post("/allocations/", json=allocation_data)
#     assignment_id = allocation_data["project_assignment_id"]
#
#     response = client.get(f"/project-assignments/{assignment_id}/allocations")
#     assert response.status_code == 200
#     data = response.json()
#     assert len(data) >= 1
#     assert data[0]["project_assignment_id"] == assignment_id
#
#
# def test_get_user_allocation_summary(client: TestClient, allocation_data: Dict[str, Any], assignment_prereqs):
#     """Tests calculating the total allocated hours per month for a user."""
#     client.post("/allocations/", json=allocation_data)
#     user_id = assignment_prereqs["user_id"] # User was created in the prereq fixture
#
#     response = client.get(f"/users/{user_id}/allocation-summary")
#     assert response.status_code == 200
#     data = response.json()
#     assert isinstance(data, list)
#     assert len(data) >= 1
#     summary_item = data[0]
#     assert summary_item["year"] == allocation_data["year"]
#     assert summary_item["month"] == allocation_data["month"]
#     assert summary_item["total_hours"] == allocation_data["allocated_hours"]

# %% [markdown]
# ### Generating Edge Cases

# %%
# TODO: CHANGE THIS PROMPT and ADD GENERATED EDGE CASES TO TESTING FILE
edge_case_tests_prompt = f"""
You are a senior QA Engineer. Generate pytest test functions for edge cases and error scenarios in a FastAPI application.

FastAPI Application Code:
{app_code}

Requirements:
1. Use FastAPI's TestClient from fastapi.testclient import TestClient
2. Import the FastAPI app instance (same setup as happy path tests)
3. Write a test function for POST /users/ that:
   - First creates a user with a valid email
   - Then attempts to create another user with the same email
   - Asserts status code is 400 (Bad Request)
   - Verifies the error message indicates duplicate email
4. Write a test function for GET /users/{{user_id}} that:
   - Requests a user ID that does not exist (e.g., 99999 or a high number)
   - Asserts status code is 404 (Not Found)
   - Verifies an appropriate error message

Output only valid Python pytest functions with proper imports. Use descriptive function names like test_create_user_duplicate_email and test_get_user_not_found. Ensure tests use the same database setup pattern as happy path tests.
"""

print("--- Generating Edge Case Tests ---")
if app_code:
    generated_edge_case_tests = get_completion(edge_case_tests_prompt, client, model_name, api_provider)
    cleaned_edge_case_tests = clean_llm_output(generated_edge_case_tests, language='python')
    print(cleaned_edge_case_tests)
else:
    print("Skipping test generation because app code is missing.")
